# %%
# %pylab inline
from matplotlib import pyplot as plt
import scipy.stats as stats
import pandas as pd
from pprint import pprint
from sklearn.metrics import log_loss

from blue.eda import response_histogram, plot_ace_scores, plot_rf_feature_importance, rf_shuffle_feature_importance
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load data
df = pd.read_csv('./data/training.csv')

# %%
# %run feature_engineering
derive_features(df)

for column in df.columns:
    print column
    
predictors = [col for col in df.columns if col not in['production', 'min_ANNmuon', 'id', 'mass']]
# Out:
# id
# LifeTime
# dira
# FlightDistance
# FlightDistanceError
# IP
# IPSig
# VertexChi2
# pt
# DOCAone
# DOCAtwo
# DOCAthree
# IP_p0p2
# IP_p1p2
# isolationa
# isolationb
# isolationc
# isolationd
# isolatione
# isolationf
# iso
# CDF1
# CDF2
# CDF3
# ISO_SumBDT
# p0_IsoBDT
# p1_IsoBDT
# p2_IsoBDT
# p0_track_Chi2Dof
# p1_track_Chi2Dof
# p2_track_Chi2Dof
# p0_IP
# p1_IP
# p2_IP
# p0_IPSig
# p1_IPSig
# p2_IPSig
# p0_pt
# p1_pt
# p2_pt
# p0_p
# p1_p
# p2_p
# p0_eta
# p1_eta
# p2_eta
# SPDhits
# production
# signal
# mass
# min_ANNmuon
# JOSH_delta_eta_p0p1
# JOSH_delta_eta_p0p2
# JOSH_delta_eta_p1p2
# JOSH_ratio_eta_p0p1
# JOSH_ratio_eta_p0p2
# JOSH_ratio_eta_p1p2
# JOSH_pt_p0p1
# JOSH_pt_p0p2
# JOSH_pt_p1p2
# JOSH_asym_pt0pt1
# JOSH_asym_pt0pt2
# JOSH_asym_pt1pt2
# JOSH_p0_pz
# JOSH_p1_pz
# JOSH_p2_pz
# JOSH_ml_p0p1
# JOSH_ml_p0p2
# JOSH_ml_p1p2
# JOSH_tau_p0_pt_ratio
# JOSH_tau_p1_pt_ratio
# JOSH_tau_p2_pt_ratio
# JOSH_IP_norm
# JOSH_IP_dira
# JOSH_FlightDistance_norm
# ...

# %%
# visualize the distributions and there relationship to the ground truth
for column in df.columns:
    if column != 'signal':
        response_histogram(df[column], df.signal, bins=50, statistic='mean', xlabel=column)
# Out:
# /Users/jdl67/Library/Python/2.7/lib/python/site-packages/matplotlib-1.5.x-py2.7-macosx-10.8-x86_64.egg/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %%
plt.figure(figsize=(20,20))
plot_ace_scores(df[predictors], 'signal', cat_cols=[], cv=False, metric=log_loss)

# %%
plt.figure(figsize=(20,20))
plot_rf_feature_importance(df[predictors], 'signal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-06aef6b68336> in <module>()
#       1 plt.figure(figsize=(20,20))
# ----> 2 plot_rf_feature_importance(df[predictors], 'signal')
#
# NameError: name 'plot_rf_feature_importance' is not defined

# %%
scores=rf_shuffle_feature_importance(df[predictors], 'signal', n_iter=3, metric=log_loss, test_size=0.5)

# %%
scores
# Out:
#    LifeTime      dira  FlightDistance  FlightDistanceError       IP     IPSig  \
# 0 -0.024132 -0.005187        0.000677            -0.003157 -0.00609 -0.098331
#
#    VertexChi2        pt   DOCAone   DOCAtwo    ...     JOSH_ml_p0p1  \
# 0   -0.080514  0.001353 -0.002255 -0.001579    ...        -0.003158
#
#    JOSH_ml_p0p2  JOSH_ml_p1p2  JOSH_tau_p0_pt_ratio  JOSH_tau_p1_pt_ratio  \
# 0     -0.002932      0.003383              0.001804             -0.003834
#
#    JOSH_tau_p2_pt_ratio  JOSH_IP_norm  JOSH_IP_dira  JOSH_FlightDistance_norm  \
# 0             -0.001804      0.006315     -0.004511                 -0.009247
#
#    JOSH_LifeTime_FlightDistance
# 0                     -0.009472
#
# [1 rows x 71 columns]
