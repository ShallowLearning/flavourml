# %%
# %load_ext autoreload
# %pylab inline
# %autoreload 2
from matplotlib import pyplot as plt
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from blue.featurelist import FeatureList
from blue.pandas_utils import get_columns_in_df

# Load featurelists
flist = FeatureList(df, spec='features.yml', derived_list=None)#'derived_features_noIP')

# %%
# load train / test data
df = pd.read_csv('./data/training.csv', index_col='id')
df = get_columns_in_df(df, flist.universe)

df_test = pd.read_csv('./data/test.csv')
df_test = get_columns_in_df(df, flist.universe)

# %%
from blue.eda import response_histogram

# visualize features
for var in flist.predictors:
    response_histogram(df[var], df[flist.target], bins=50, statistic='mean', xlabel=var)

# %%
from blue.eda import plot_ace_scores
from sklearn.metrics import log_loss

plt.figure(figsize=(20,20))
plot_ace_scores(df[flist.predictors], flist.target, cat_cols=[], cv=False, metric=log_loss)

# %%
from evaluation import roc_auc_truncated, ModelValidator
validator = ModelValidator(flist)
valid = validator.validate(xgb_modeler)
print valid
np.mean(xgb_modeler.scores)
# Out:
# {'agreement': {'value': 0.12527257578102491, 'pass': False}, 'correlation': {'value': 0.0009858073222449124, 'pass': True}}
# 0.97855258791984578

# %%
from blue.modelers.modeler import Modeler 
from sklearn.ensemble import RandomForestClassifier
from evaluation import roc_auc_truncated

rf = RandomForestClassifier(n_estimators=200, random_state=1234)

modeler = Modeler(rf, flist.target, roc_auc_truncated, features=flist.predictors, n_folds=5)
modeler.fit(df)

# %%
from blue.estimators.xgboost import XGBoostClassifier
xgb = XGBoostClassifier(nthreads=4, eta=0.2, n_estimators=450, colsample=0.7)

xgb_modeler = Modeler(xgb, flist.target, roc_auc_truncated, features=flist.predictors, n_folds=2)
xgb_modeler.fit(df)

# %%
df_test = pd.read_csv('./data/test.csv')
rf_preds = modeler.predict_proba(df_test, features=flist.predictors)

# %%
xgb_preds = modeler.predict_proba(df_test, features=flist.predictors)

# %%
submit = pd.DataFrame({'id': df_test.id.values, 'prediction': 0.5 * rf_preds[:,1] + 0.5*xgb_preds[:,1]})
submit.to_csv('xgb_rf_test.csv', index=False)
